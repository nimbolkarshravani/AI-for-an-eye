# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
COLAB = True
print("Note: using Google CoLab")
# %tensorflow_version 2.x
# Out:
# Mounted at /content/drive
# Note: using Google CoLab

# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import pandas as pd
import cv2
import pickle
import matplotlib.pyplot as plt
import tensorflow as tf

from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

from sklearn.model_selection import train_test_split
# %matplotlib inline

# %%
image_data = "/content/drive/My Drive/DMW/pickled_data.txt"
data = "/content/drive/My Drive/DMW/Preprocessing/normal/"

# %%
normal_left_y = pd.read_csv(data + 'normal_left.csv').iloc[:,3]
normal_left_n = pd.read_csv(data + 'not_normal_left.csv').iloc[:,3]

normal_right_y = pd.read_csv(data + 'normal_right.csv').iloc[:,3]
normal_right_n = pd.read_csv(data + 'not_normal_right.csv').iloc[:,3]

# %%
x_l = []
y_l = []
x_r = []
y_r = []
size_l = 50
size_b = 50

myfile = open(image_data, mode='rb')
temp = pickle.load(myfile)
myfile.close()

# count = 0
for image_name in normal_left_y:
  try:
    # count += 1
    image = temp[image_name]
    image = cv2.resize(image, (size_l, size_b))
    x_l.append(image)
    y_l.append(1)
    # if count % 100 == 0:
    #   print(count, 'done')
  except:
    print(image_name)
    break

for image_name in normal_left_n:
  try:
    # count += 1
    image = temp[image_name]
    image = cv2.resize(image, (size_l, size_b))
    x_l.append(image)
    y_l.append(0)
    # if count % 100 == 0:
    #   print(count, 'done')
  except:
    print(image_name)
    break


for image_name in normal_right_y:
  try:
    # count += 1
    image = temp[image_name]
    image = cv2.resize(image, (size_l, size_b))
    x_r.append(image)
    y_r.append(1)
    # if count % 100 == 0:
    #   print(count, 'done')
  except:
    print(image_name)
    break

for image_name in normal_right_n:
  try:
    # count += 1
    image = temp[image_name]
    image = cv2.resize(image, (size_l, size_b))
    x_r.append(image)
    y_r.append(0)
    # if count % 100 == 0:
    #   print(count, 'done')
  except:
    print(image_name)
    break

temp.clear()
print('data loaded')
# Out:
# data loaded

# %%
x_l_np = np.asarray(x_l)
y_l_np = np.asarray(y_l)
x_r_np = np.asarray(x_r)
y_r_np = np.asarray(y_r)

x_l_np.shape, y_l_np.shape, x_r_np.shape, y_r_np.shape
# Out:
# ((3500, 50, 50, 3), (3500,), (3500, 50, 50, 3), (3500,))

# %%
X_l_train, X_l_test, y_l_train, y_l_test = train_test_split(x_l_np, y_l_np, test_size=0.1, random_state=42)
X_r_train, X_r_test, y_r_train, y_r_test = train_test_split(x_r_np, y_r_np, test_size=0.1, random_state=42)

# %%
model_l = Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(size_l, size_b, 3)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(34, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64),
    layers.Dense(1, activation='sigmoid')
])

model_l.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_l.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_7 (Rescaling)      (None, 50, 50, 3)         0
# _________________________________________________________________
# conv2d_14 (Conv2D)           (None, 48, 48, 16)        448
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 24, 24, 16)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 22, 22, 34)        4930
# _________________________________________________________________
# max_pooling2d_15 (MaxPooling (None, 11, 11, 34)        0
# _________________________________________________________________
# flatten_7 (Flatten)          (None, 4114)              0
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                263360
# _________________________________________________________________
# dense_15 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 268,803
# Trainable params: 268,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs_l = 100
batch_size_l = 20
history_l = model_l.fit(x_l_np, y_l_np, batch_size=batch_size_l, epochs=epochs_l, validation_data=(X_l_test,y_l_test))
# Out:
# Epoch 1/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.6875 - accuracy: 0.5634 - val_loss: 0.6855 - val_accuracy: 0.5229
# Epoch 2/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6810 - accuracy: 0.5726 - val_loss: 0.6765 - val_accuracy: 0.5629
# Epoch 3/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6730 - accuracy: 0.5894 - val_loss: 0.6676 - val_accuracy: 0.6000
# Epoch 4/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6657 - accuracy: 0.5946 - val_loss: 0.6691 - val_accuracy: 0.5943
# Epoch 5/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6609 - accuracy: 0.6054 - val_loss: 0.6668 - val_accuracy: 0.5600
# Epoch 6/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6547 - accuracy: 0.6126 - val_loss: 0.6565 - val_accuracy: 0.5829
# Epoch 7/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6529 - accuracy: 0.6089 - val_loss: 0.6425 - val_accuracy: 0.6171
# Epoch 8/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6485 - accuracy: 0.6180 - val_loss: 0.6354 - val_accuracy: 0.6486
# Epoch 9/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6399 - accuracy: 0.6303 - val_loss: 0.6184 - val_accuracy: 0.6314
# Epoch 10/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.6317 - val_loss: 0.6337 - val_accuracy: 0.6371
# Epoch 11/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6234 - accuracy: 0.6451 - val_loss: 0.6035 - val_accuracy: 0.6514
# Epoch 12/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6180 - accuracy: 0.6443 - val_loss: 0.6210 - val_accuracy: 0.6429
# Epoch 13/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6133 - accuracy: 0.6440 - val_loss: 0.5997 - val_accuracy: 0.6629
# Epoch 14/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6107 - accuracy: 0.6491 - val_loss: 0.6093 - val_accuracy: 0.6314
# Epoch 15/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6004 - accuracy: 0.6554 - val_loss: 0.6074 - val_accuracy: 0.6257
# Epoch 16/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5919 - accuracy: 0.6680 - val_loss: 0.6045 - val_accuracy: 0.6600
# Epoch 17/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5930 - accuracy: 0.6629 - val_loss: 0.6009 - val_accuracy: 0.6571
# Epoch 18/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5771 - accuracy: 0.6703 - val_loss: 0.5746 - val_accuracy: 0.6543
# Epoch 19/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5678 - accuracy: 0.6894 - val_loss: 0.5519 - val_accuracy: 0.7114
# Epoch 20/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5554 - accuracy: 0.6963 - val_loss: 0.5548 - val_accuracy: 0.6686
# Epoch 21/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5494 - accuracy: 0.7049 - val_loss: 0.5344 - val_accuracy: 0.7029
# Epoch 22/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5446 - accuracy: 0.7123 - val_loss: 0.5517 - val_accuracy: 0.6886
# Epoch 23/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5329 - accuracy: 0.7191 - val_loss: 0.5290 - val_accuracy: 0.6943
# Epoch 24/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5226 - accuracy: 0.7246 - val_loss: 0.5296 - val_accuracy: 0.7143
# Epoch 25/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.5109 - accuracy: 0.7286 - val_loss: 0.5265 - val_accuracy: 0.6943
# Epoch 26/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.4954 - accuracy: 0.7371 - val_loss: 0.5470 - val_accuracy: 0.7029
# Epoch 27/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4889 - accuracy: 0.7466 - val_loss: 0.4897 - val_accuracy: 0.7314
# Epoch 28/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4811 - accuracy: 0.7546 - val_loss: 0.4769 - val_accuracy: 0.7571
# Epoch 29/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4716 - accuracy: 0.7603 - val_loss: 0.4916 - val_accuracy: 0.7371
# Epoch 30/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4579 - accuracy: 0.7657 - val_loss: 0.4686 - val_accuracy: 0.7314
# Epoch 31/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4521 - accuracy: 0.7740 - val_loss: 0.4747 - val_accuracy: 0.7514
# Epoch 32/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4476 - accuracy: 0.7780 - val_loss: 0.4627 - val_accuracy: 0.7457
# Epoch 33/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4287 - accuracy: 0.7954 - val_loss: 0.4345 - val_accuracy: 0.7914
# Epoch 34/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4268 - accuracy: 0.7909 - val_loss: 0.4125 - val_accuracy: 0.7971
# Epoch 35/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4135 - accuracy: 0.7969 - val_loss: 0.3934 - val_accuracy: 0.8086
# Epoch 36/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3929 - accuracy: 0.8089 - val_loss: 0.4339 - val_accuracy: 0.7743
# Epoch 37/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3837 - accuracy: 0.8209 - val_loss: 0.3573 - val_accuracy: 0.8314
# Epoch 38/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3793 - accuracy: 0.8189 - val_loss: 0.3526 - val_accuracy: 0.8286
# Epoch 39/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3723 - accuracy: 0.8231 - val_loss: 0.3450 - val_accuracy: 0.8486
# Epoch 40/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3580 - accuracy: 0.8357 - val_loss: 0.3255 - val_accuracy: 0.8743
# Epoch 41/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3421 - accuracy: 0.8423 - val_loss: 0.3483 - val_accuracy: 0.8371
# Epoch 42/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3353 - accuracy: 0.8489 - val_loss: 0.4121 - val_accuracy: 0.8029
# Epoch 43/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3396 - accuracy: 0.8403 - val_loss: 0.3714 - val_accuracy: 0.8171
# Epoch 44/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3425 - accuracy: 0.8406 - val_loss: 0.3201 - val_accuracy: 0.8629
# Epoch 45/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3102 - accuracy: 0.8580 - val_loss: 0.3214 - val_accuracy: 0.8400
# Epoch 46/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3437 - accuracy: 0.8400 - val_loss: 0.3459 - val_accuracy: 0.8200
# Epoch 47/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3263 - accuracy: 0.8517 - val_loss: 0.3062 - val_accuracy: 0.8486
# Epoch 48/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2953 - accuracy: 0.8611 - val_loss: 0.2883 - val_accuracy: 0.8629
# Epoch 49/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2846 - accuracy: 0.8726 - val_loss: 0.3027 - val_accuracy: 0.8571
# Epoch 50/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2603 - accuracy: 0.8849 - val_loss: 0.2521 - val_accuracy: 0.8914
# Epoch 51/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2670 - accuracy: 0.8803 - val_loss: 0.2849 - val_accuracy: 0.8771
# Epoch 52/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.2876 - accuracy: 0.8671 - val_loss: 0.2545 - val_accuracy: 0.8857
# Epoch 53/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2516 - accuracy: 0.8891 - val_loss: 0.2515 - val_accuracy: 0.9000
# Epoch 54/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2462 - accuracy: 0.8929 - val_loss: 0.1968 - val_accuracy: 0.9171
# Epoch 55/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2551 - accuracy: 0.8889 - val_loss: 0.2766 - val_accuracy: 0.8771
# Epoch 56/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2427 - accuracy: 0.8954 - val_loss: 0.2712 - val_accuracy: 0.8886
# Epoch 57/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.2248 - accuracy: 0.9037 - val_loss: 0.2835 - val_accuracy: 0.8771
# Epoch 58/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2366 - accuracy: 0.8940 - val_loss: 0.2192 - val_accuracy: 0.8886
# Epoch 59/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2239 - accuracy: 0.9003 - val_loss: 0.2532 - val_accuracy: 0.9000
# Epoch 60/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2374 - accuracy: 0.8977 - val_loss: 0.3188 - val_accuracy: 0.8629
# Epoch 61/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2176 - accuracy: 0.9071 - val_loss: 0.1407 - val_accuracy: 0.9486
# Epoch 62/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.1946 - accuracy: 0.9166 - val_loss: 0.3233 - val_accuracy: 0.8857
# Epoch 63/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2192 - accuracy: 0.9074 - val_loss: 0.2338 - val_accuracy: 0.9000
# Epoch 64/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2082 - accuracy: 0.9091 - val_loss: 0.1510 - val_accuracy: 0.9629
# Epoch 65/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1923 - accuracy: 0.9194 - val_loss: 0.2046 - val_accuracy: 0.9143
# Epoch 66/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2273 - accuracy: 0.9046 - val_loss: 0.2576 - val_accuracy: 0.8829
# Epoch 67/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2074 - accuracy: 0.9080 - val_loss: 0.1468 - val_accuracy: 0.9371
# Epoch 68/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1765 - accuracy: 0.9271 - val_loss: 0.2150 - val_accuracy: 0.8971
# Epoch 69/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1757 - accuracy: 0.9243 - val_loss: 0.1387 - val_accuracy: 0.9371
# Epoch 70/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1637 - accuracy: 0.9323 - val_loss: 0.1518 - val_accuracy: 0.9457
# Epoch 71/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1674 - accuracy: 0.9309 - val_loss: 0.1736 - val_accuracy: 0.9229
# Epoch 72/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1435 - accuracy: 0.9451 - val_loss: 0.1475 - val_accuracy: 0.9457
# Epoch 73/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1708 - accuracy: 0.9300 - val_loss: 0.1366 - val_accuracy: 0.9457
# Epoch 74/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1882 - accuracy: 0.9200 - val_loss: 0.1295 - val_accuracy: 0.9486
# Epoch 75/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2013 - accuracy: 0.9200 - val_loss: 0.1626 - val_accuracy: 0.9343
# Epoch 76/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1491 - accuracy: 0.9394 - val_loss: 0.1084 - val_accuracy: 0.9600
# Epoch 77/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.1672 - accuracy: 0.9340 - val_loss: 0.2049 - val_accuracy: 0.9371
# Epoch 78/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1717 - accuracy: 0.9283 - val_loss: 0.3477 - val_accuracy: 0.8600
# Epoch 79/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1561 - accuracy: 0.9366 - val_loss: 0.0899 - val_accuracy: 0.9714
# Epoch 80/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1173 - accuracy: 0.9534 - val_loss: 0.1479 - val_accuracy: 0.9486
# Epoch 81/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1714 - accuracy: 0.9311 - val_loss: 0.1205 - val_accuracy: 0.9600
# Epoch 82/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1763 - accuracy: 0.9314 - val_loss: 0.1202 - val_accuracy: 0.9629
# Epoch 83/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1746 - accuracy: 0.9311 - val_loss: 0.1065 - val_accuracy: 0.9629
# Epoch 84/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1254 - accuracy: 0.9517 - val_loss: 0.0895 - val_accuracy: 0.9771
# Epoch 85/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1236 - accuracy: 0.9509 - val_loss: 0.0949 - val_accuracy: 0.9629
# Epoch 86/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1083 - accuracy: 0.9583 - val_loss: 0.1178 - val_accuracy: 0.9514
# Epoch 87/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1136 - accuracy: 0.9560 - val_loss: 0.2481 - val_accuracy: 0.9286
# Epoch 88/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1565 - accuracy: 0.9380 - val_loss: 0.1008 - val_accuracy: 0.9686
# Epoch 89/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2318 - accuracy: 0.9134 - val_loss: 0.1802 - val_accuracy: 0.9314
# Epoch 90/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1674 - accuracy: 0.9343 - val_loss: 0.0874 - val_accuracy: 0.9743
# Epoch 91/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0742 - accuracy: 0.9766 - val_loss: 0.0683 - val_accuracy: 0.9714
# Epoch 92/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0696 - accuracy: 0.9760 - val_loss: 0.0723 - val_accuracy: 0.9743
# Epoch 93/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0778 - accuracy: 0.9731 - val_loss: 0.0786 - val_accuracy: 0.9743
# Epoch 94/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1723 - accuracy: 0.9414 - val_loss: 0.1123 - val_accuracy: 0.9571
# Epoch 95/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2282 - accuracy: 0.9131 - val_loss: 0.1555 - val_accuracy: 0.9514
# Epoch 96/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1024 - accuracy: 0.9649 - val_loss: 0.0625 - val_accuracy: 0.9829
# Epoch 97/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.0614 - accuracy: 0.9809 - val_loss: 0.0743 - val_accuracy: 0.9714
# Epoch 98/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0727 - accuracy: 0.9737 - val_loss: 0.0493 - val_accuracy: 0.9914
# Epoch 99/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0969 - accuracy: 0.9649 - val_loss: 0.0828 - val_accuracy: 0.9714
# Epoch 100/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1228 - accuracy: 0.9529 - val_loss: 0.1545 - val_accuracy: 0.9457

# %%
model_r = Sequential([
    layers.experimental.preprocessing.Rescaling(1./255, input_shape=(size_l, size_b, 3)),
    layers.Conv2D(16, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Conv2D(34, (3, 3), activation='relu'),
    layers.MaxPooling2D(),
    layers.Flatten(),
    layers.Dense(64),
    layers.Dense(1, activation='sigmoid')
])

model_r.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

model_r.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# rescaling_8 (Rescaling)      (None, 50, 50, 3)         0
# _________________________________________________________________
# conv2d_16 (Conv2D)           (None, 48, 48, 16)        448
# _________________________________________________________________
# max_pooling2d_16 (MaxPooling (None, 24, 24, 16)        0
# _________________________________________________________________
# conv2d_17 (Conv2D)           (None, 22, 22, 34)        4930
# _________________________________________________________________
# max_pooling2d_17 (MaxPooling (None, 11, 11, 34)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 4114)              0
# _________________________________________________________________
# dense_16 (Dense)             (None, 64)                263360
# _________________________________________________________________
# dense_17 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 268,803
# Trainable params: 268,803
# Non-trainable params: 0
# _________________________________________________________________

# %%
epochs_r = 100
batch_size_r = 20
history_r = model_r.fit(x_r_np, y_r_np, batch_size=batch_size_r, epochs=epochs_r, validation_data=(X_r_test,y_r_test))
# Out:
# Epoch 1/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.6849 - accuracy: 0.5666 - val_loss: 0.6754 - val_accuracy: 0.6200
# Epoch 2/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6711 - accuracy: 0.5906 - val_loss: 0.6689 - val_accuracy: 0.6057
# Epoch 3/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6681 - accuracy: 0.5914 - val_loss: 0.6832 - val_accuracy: 0.5886
# Epoch 4/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6624 - accuracy: 0.6009 - val_loss: 0.6740 - val_accuracy: 0.5571
# Epoch 5/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6598 - accuracy: 0.6163 - val_loss: 0.6595 - val_accuracy: 0.6114
# Epoch 6/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6564 - accuracy: 0.6194 - val_loss: 0.6556 - val_accuracy: 0.6229
# Epoch 7/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.6541 - accuracy: 0.6231 - val_loss: 0.6433 - val_accuracy: 0.6343
# Epoch 8/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6464 - accuracy: 0.6189 - val_loss: 0.6381 - val_accuracy: 0.6457
# Epoch 9/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6441 - accuracy: 0.6237 - val_loss: 0.6415 - val_accuracy: 0.6000
# Epoch 10/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6355 - accuracy: 0.6326 - val_loss: 0.6110 - val_accuracy: 0.6571
# Epoch 11/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6270 - accuracy: 0.6400 - val_loss: 0.6140 - val_accuracy: 0.6800
# Epoch 12/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6214 - accuracy: 0.6506 - val_loss: 0.6072 - val_accuracy: 0.6400
# Epoch 13/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.6139 - accuracy: 0.6386 - val_loss: 0.6173 - val_accuracy: 0.6314
# Epoch 14/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6028 - accuracy: 0.6634 - val_loss: 0.5797 - val_accuracy: 0.6971
# Epoch 15/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.6022 - accuracy: 0.6634 - val_loss: 0.5711 - val_accuracy: 0.6886
# Epoch 16/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.5841 - accuracy: 0.6720 - val_loss: 0.5634 - val_accuracy: 0.7114
# Epoch 17/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5869 - accuracy: 0.6737 - val_loss: 0.5474 - val_accuracy: 0.7286
# Epoch 18/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.5785 - accuracy: 0.6817 - val_loss: 0.5433 - val_accuracy: 0.7114
# Epoch 19/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5650 - accuracy: 0.6886 - val_loss: 0.5384 - val_accuracy: 0.7200
# Epoch 20/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5540 - accuracy: 0.6951 - val_loss: 0.6057 - val_accuracy: 0.6429
# Epoch 21/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5486 - accuracy: 0.7071 - val_loss: 0.5419 - val_accuracy: 0.7114
# Epoch 22/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.5470 - accuracy: 0.7077 - val_loss: 0.5024 - val_accuracy: 0.7429
# Epoch 23/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.5314 - accuracy: 0.7211 - val_loss: 0.4763 - val_accuracy: 0.7886
# Epoch 24/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.5206 - accuracy: 0.7254 - val_loss: 0.4701 - val_accuracy: 0.7486
# Epoch 25/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.5101 - accuracy: 0.7374 - val_loss: 0.4902 - val_accuracy: 0.7457
# Epoch 26/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.5030 - accuracy: 0.7374 - val_loss: 0.4785 - val_accuracy: 0.7657
# Epoch 27/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4832 - accuracy: 0.7466 - val_loss: 0.4706 - val_accuracy: 0.7543
# Epoch 28/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4736 - accuracy: 0.7631 - val_loss: 0.4189 - val_accuracy: 0.8086
# Epoch 29/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4801 - accuracy: 0.7460 - val_loss: 0.4637 - val_accuracy: 0.7686
# Epoch 30/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.4590 - accuracy: 0.7686 - val_loss: 0.4235 - val_accuracy: 0.7800
# Epoch 31/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4352 - accuracy: 0.7854 - val_loss: 0.4771 - val_accuracy: 0.7486
# Epoch 32/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4160 - accuracy: 0.7931 - val_loss: 0.3991 - val_accuracy: 0.8029
# Epoch 33/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.4168 - accuracy: 0.7903 - val_loss: 0.3827 - val_accuracy: 0.8343
# Epoch 34/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4050 - accuracy: 0.7969 - val_loss: 0.3463 - val_accuracy: 0.8400
# Epoch 35/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.4060 - accuracy: 0.8063 - val_loss: 0.3699 - val_accuracy: 0.8257
# Epoch 36/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3834 - accuracy: 0.8189 - val_loss: 0.3386 - val_accuracy: 0.8629
# Epoch 37/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3725 - accuracy: 0.8209 - val_loss: 0.3450 - val_accuracy: 0.8714
# Epoch 38/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3831 - accuracy: 0.8151 - val_loss: 0.3338 - val_accuracy: 0.8543
# Epoch 39/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.3520 - accuracy: 0.8383 - val_loss: 0.3093 - val_accuracy: 0.8714
# Epoch 40/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3553 - accuracy: 0.8403 - val_loss: 0.3252 - val_accuracy: 0.8486
# Epoch 41/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3393 - accuracy: 0.8417 - val_loss: 0.3024 - val_accuracy: 0.8486
# Epoch 42/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3320 - accuracy: 0.8503 - val_loss: 0.3628 - val_accuracy: 0.8143
# Epoch 43/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3108 - accuracy: 0.8531 - val_loss: 0.3448 - val_accuracy: 0.8314
# Epoch 44/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3294 - accuracy: 0.8471 - val_loss: 0.2873 - val_accuracy: 0.8829
# Epoch 45/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3225 - accuracy: 0.8549 - val_loss: 0.3076 - val_accuracy: 0.8714
# Epoch 46/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.3109 - accuracy: 0.8600 - val_loss: 0.2496 - val_accuracy: 0.8971
# Epoch 47/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2591 - accuracy: 0.8829 - val_loss: 0.2542 - val_accuracy: 0.9000
# Epoch 48/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2700 - accuracy: 0.8811 - val_loss: 0.2517 - val_accuracy: 0.8943
# Epoch 49/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2808 - accuracy: 0.8774 - val_loss: 0.2336 - val_accuracy: 0.9057
# Epoch 50/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.3331 - accuracy: 0.8474 - val_loss: 0.2565 - val_accuracy: 0.8943
# Epoch 51/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2621 - accuracy: 0.8843 - val_loss: 0.2288 - val_accuracy: 0.8914
# Epoch 52/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2689 - accuracy: 0.8826 - val_loss: 0.3436 - val_accuracy: 0.8371
# Epoch 53/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2419 - accuracy: 0.8986 - val_loss: 0.1953 - val_accuracy: 0.9114
# Epoch 54/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2316 - accuracy: 0.8960 - val_loss: 0.2079 - val_accuracy: 0.9114
# Epoch 55/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2178 - accuracy: 0.9106 - val_loss: 0.3196 - val_accuracy: 0.8571
# Epoch 56/100
# 175/175 [==============================] - 0s 2ms/step - loss: 0.2392 - accuracy: 0.8949 - val_loss: 0.1914 - val_accuracy: 0.9200
# Epoch 57/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2033 - accuracy: 0.9149 - val_loss: 0.2209 - val_accuracy: 0.9171
# Epoch 58/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2300 - accuracy: 0.9000 - val_loss: 0.1857 - val_accuracy: 0.9171
# Epoch 59/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2129 - accuracy: 0.9094 - val_loss: 0.2265 - val_accuracy: 0.8943
# Epoch 60/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2234 - accuracy: 0.9029 - val_loss: 0.2133 - val_accuracy: 0.9086
# Epoch 61/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1948 - accuracy: 0.9166 - val_loss: 0.2319 - val_accuracy: 0.9086
# Epoch 62/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1901 - accuracy: 0.9237 - val_loss: 0.1731 - val_accuracy: 0.9229
# Epoch 63/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2308 - accuracy: 0.9037 - val_loss: 0.1622 - val_accuracy: 0.9286
# Epoch 64/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1665 - accuracy: 0.9340 - val_loss: 0.1190 - val_accuracy: 0.9600
# Epoch 65/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1618 - accuracy: 0.9334 - val_loss: 0.2436 - val_accuracy: 0.8971
# Epoch 66/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2145 - accuracy: 0.9086 - val_loss: 0.1956 - val_accuracy: 0.9429
# Epoch 67/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1668 - accuracy: 0.9329 - val_loss: 0.0951 - val_accuracy: 0.9743
# Epoch 68/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1665 - accuracy: 0.9311 - val_loss: 0.2684 - val_accuracy: 0.8886
# Epoch 69/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2066 - accuracy: 0.9220 - val_loss: 0.1912 - val_accuracy: 0.9314
# Epoch 70/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1814 - accuracy: 0.9263 - val_loss: 0.1004 - val_accuracy: 0.9629
# Epoch 71/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1327 - accuracy: 0.9466 - val_loss: 0.1667 - val_accuracy: 0.9171
# Epoch 72/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1757 - accuracy: 0.9274 - val_loss: 0.1238 - val_accuracy: 0.9457
# Epoch 73/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1269 - accuracy: 0.9514 - val_loss: 0.1022 - val_accuracy: 0.9600
# Epoch 74/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1444 - accuracy: 0.9477 - val_loss: 0.1952 - val_accuracy: 0.9143
# Epoch 75/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.2413 - accuracy: 0.9057 - val_loss: 0.1419 - val_accuracy: 0.9514
# Epoch 76/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1690 - accuracy: 0.9309 - val_loss: 0.1036 - val_accuracy: 0.9743
# Epoch 77/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1356 - accuracy: 0.9463 - val_loss: 0.1202 - val_accuracy: 0.9571
# Epoch 78/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1240 - accuracy: 0.9520 - val_loss: 0.0759 - val_accuracy: 0.9800
# Epoch 79/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1168 - accuracy: 0.9577 - val_loss: 0.0882 - val_accuracy: 0.9743
# Epoch 80/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1074 - accuracy: 0.9571 - val_loss: 0.1583 - val_accuracy: 0.9400
# Epoch 81/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1620 - accuracy: 0.9320 - val_loss: 0.3617 - val_accuracy: 0.8686
# Epoch 82/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1574 - accuracy: 0.9320 - val_loss: 0.1534 - val_accuracy: 0.9229
# Epoch 83/100
# 175/175 [==============================] - 1s 3ms/step - loss: 0.1716 - accuracy: 0.9337 - val_loss: 0.2173 - val_accuracy: 0.9343
# Epoch 84/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1438 - accuracy: 0.9414 - val_loss: 0.1178 - val_accuracy: 0.9543
# Epoch 85/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0729 - accuracy: 0.9789 - val_loss: 0.0702 - val_accuracy: 0.9743
# Epoch 86/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1692 - accuracy: 0.9383 - val_loss: 0.1434 - val_accuracy: 0.9571
# Epoch 87/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1707 - accuracy: 0.9374 - val_loss: 0.0880 - val_accuracy: 0.9629
# Epoch 88/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0863 - accuracy: 0.9674 - val_loss: 0.0571 - val_accuracy: 0.9829
# Epoch 89/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1321 - accuracy: 0.9514 - val_loss: 0.0772 - val_accuracy: 0.9686
# Epoch 90/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1331 - accuracy: 0.9514 - val_loss: 0.1229 - val_accuracy: 0.9543
# Epoch 91/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1391 - accuracy: 0.9420 - val_loss: 0.1833 - val_accuracy: 0.9343
# Epoch 92/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1398 - accuracy: 0.9443 - val_loss: 0.1027 - val_accuracy: 0.9543
# Epoch 93/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1089 - accuracy: 0.9546 - val_loss: 0.0844 - val_accuracy: 0.9743
# Epoch 94/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0815 - accuracy: 0.9706 - val_loss: 0.0947 - val_accuracy: 0.9686
# Epoch 95/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1157 - accuracy: 0.9549 - val_loss: 0.0993 - val_accuracy: 0.9714
# Epoch 96/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1499 - accuracy: 0.9409 - val_loss: 0.0739 - val_accuracy: 0.9743
# Epoch 97/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1229 - accuracy: 0.9543 - val_loss: 0.0908 - val_accuracy: 0.9629
# Epoch 98/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0740 - accuracy: 0.9709 - val_loss: 0.0544 - val_accuracy: 0.9829
# Epoch 99/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.0529 - accuracy: 0.9846 - val_loss: 0.0497 - val_accuracy: 0.9914
# Epoch 100/100
# 175/175 [==============================] - 0s 3ms/step - loss: 0.1224 - accuracy: 0.9549 - val_loss: 0.2073 - val_accuracy: 0.9314

# %%
acc = history_l.history['accuracy']
val_acc = history_l.history['val_accuracy']

loss = history_l.history['loss']
val_loss = history_l.history['val_loss']

epochs_range = range(1, epochs_l+1)

plt.figure(figsize=(25, 8))
plt.subplot(1, 2, 1)
plt.xticks(range(0, epochs_l+1, 2))
plt.grid()
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.xticks(range(0, epochs_l+1, 2))
plt.grid()
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
acc = history_r.history['accuracy']
val_acc = history_r.history['val_accuracy']

loss = history_r.history['loss']
val_loss = history_r.history['val_loss']

epochs_range = range(epochs_r)

plt.figure(figsize=(25, 8))
plt.subplot(1, 2, 1)
plt.xticks(range(0, epochs_r+1, 2))
plt.grid()
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.xticks(range(0, epochs_r+1, 2))
plt.grid()
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %%
score = model_l.evaluate(X_l_test, y_l_test)
print("%s: %.2f%%" % (model_l.metrics_names[1], score[1]*100))

score = model_r.evaluate(X_r_test, y_r_test)
print("%s: %.2f%%" % (model_r.metrics_names[1], score[1]*100))
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9457
# accuracy: 94.57%
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2073 - accuracy: 0.9314
# accuracy: 93.14%

# %%
from tensorflow.keras.models import model_from_json

model_json = model_l.to_json()
with open("/content/drive/My Drive/DMW/Preprocessing/normal/Model/Left_normal.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model_l.save_weights("/content/drive/My Drive/DMW/Preprocessing/normal/Model/Left_normal.h5")
print("Saved model to disk")

model_json = model_r.to_json()
with open("/content/drive/My Drive/DMW/Preprocessing/normal/Model/Right_normal.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
model_r.save_weights("/content/drive/My Drive/DMW/Preprocessing/normal/Model/Right_normal.h5")
print("Saved model to disk")
# Out:
# Saved model to disk
# Saved model to disk

# %%
from tensorflow.keras.models import model_from_json
# load json and create model
json_file = open('/content/drive/My Drive/DMW/Preprocessing/normal/Model/Left_normal.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model_l = model_from_json(loaded_model_json)
# load weights into new model
loaded_model_l.load_weights("/content/drive/My Drive/DMW/Preprocessing/normal/Model/Left_normal.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model_l.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy'])


# load json and create model
json_file = open('/content/drive/My Drive/DMW/Preprocessing/normal/Model/Right_normal.json', 'r')
loaded_model_json = json_file.read()
json_file.close()
loaded_model_r = model_from_json(loaded_model_json)
# load weights into new model
loaded_model_r.load_weights("/content/drive/My Drive/DMW/Preprocessing/normal/Model/Right_normal.h5")
print("Loaded model from disk")
 
# evaluate loaded model on test data
loaded_model_r.compile(optimizer='adam',
                     loss='binary_crossentropy',
                     metrics=['accuracy'])
# Out:
# Loaded model from disk
# Loaded model from disk

# %%
score = loaded_model_l.evaluate(X_l_test, y_l_test)
print("%s: %.2f%%" % (loaded_model_l.metrics_names[1], score[1]*100))

score = loaded_model_r.evaluate(X_r_test, y_r_test)
print("%s: %.2f%%" % (loaded_model_r.metrics_names[1], score[1]*100))
# Out:
# 11/11 [==============================] - 0s 2ms/step - loss: 0.1545 - accuracy: 0.9457
# accuracy: 94.57%
# 11/11 [==============================] - 0s 2ms/step - loss: 0.2073 - accuracy: 0.9314
# accuracy: 93.14%

# %%
from sklearn.metrics import confusion_matrix
y_pred_l = loaded_model_l.predict(x_l_np)
y_pred_l = np.asarray([y > 0.5 for y in y_pred_l])
y_pred_r = loaded_model_l.predict(x_r_np)
y_pred_r = np.asarray([y > 0.5 for y in y_pred_r])

cm_l = confusion_matrix(y_l_np, y_pred_l)
cm_r = confusion_matrix(y_r_np, y_pred_r)
print(cm_l)
print(cm_r)
# Out:
# [[1681  235]
#  [  19 1565]]
# [[1747  228]
#  [ 455 1070]]
